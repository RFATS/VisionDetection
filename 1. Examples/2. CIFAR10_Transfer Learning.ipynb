# %%
# ==============================================
# 1. 라이브러리 & 하드웨어 설정
# ==============================================
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets, models
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# ==============================================
# 2. CIFAR‑10 데이터셋 & DataLoader
# ==============================================
#   - 학습용: 랜덤 크롭 + 좌우반전 + 정규화
#   - 검증용: 정규화만
# ==============================================

mean = (0.4914, 0.4822, 0.4465)
std  = (0.2470, 0.2435, 0.2616)

train_tf = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

test_tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

train_ds = datasets.CIFAR10(root="./data", train=True,  download=True, transform=train_tf)
test_ds = datasets.CIFAR10(root="./data", train=False, download=True, transform=test_tf)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,  num_workers=2, pin_memory=True)
test_loader = DataLoader(test_ds,  batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

# %%
# ==============================================
# 3. 사전학습 모델 로드 & 헤드(FC) 교체
# ==============================================
feature_extract = True

weights = models.ResNet18_Weights.IMAGENET1K_V1
model = models.resnet18(weights=weights)

for n, _ in model.named_children():
    print(n)
# Out:
# conv1
# bn1
# relu
# maxpool
# layer1
# layer2
# layer3
# layer4
# avgpool
# fc

# %%
if feature_extract:
    for p in model.parameters():
        p.requires_grad = False

for name, p in model.named_parameters():
    if "layer4" in name:
        p.requires_grad = True
# Out:
# conv1
# bn1
# relu
# maxpool
# layer1
# layer2
# layer3
# layer4
# avgpool
# fc

# %%
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 10)        # CIFAR‑10 → 10‑class

model = model.to(device)

# %%
# ==============================================
# 4. 학습 설정
# ==============================================
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-4
)

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, 1)
    return (preds == labels).float().mean().item()

# %%
# ==============================================
# 5. 학습 & 검증 루프
# ==============================================
num_epochs = 50
for epoch in range(1, num_epochs + 1):
    # ---------- Train ----------
    model.train()
    running_loss, running_acc = 0.0, 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss    = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        running_acc  += accuracy(outputs, labels) * images.size(0)

    train_loss = running_loss / len(train_loader.dataset)
    train_acc  = running_acc  / len(train_loader.dataset)

    # ---------- Eval ----------
    model.eval()
    test_loss, test_acc = 0.0, 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss    = criterion(outputs, labels)

            test_loss += loss.item() * images.size(0)
            test_acc  += accuracy(outputs, labels) * images.size(0)

    test_loss /= len(test_loader.dataset)
    test_acc  /= len(test_loader.dataset)

    print(f"[Epoch {epoch}/{num_epochs}] "
          f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc*100:.2f}% "
          f"|| Test Loss: {test_loss:.4f} | Test Acc: {test_acc*100:.2f}%")
# Out:
# [Epoch 1/50] Train Loss: 2.0676 | Train Acc: 25.91% || Test Loss: 1.9429 | Test Acc: 32.01%
# [Epoch 2/50] Train Loss: 1.8365 | Train Acc: 35.00% || Test Loss: 1.8262 | Test Acc: 36.23%
# [Epoch 3/50] Train Loss: 1.7805 | Train Acc: 37.21% || Test Loss: 1.7855 | Test Acc: 37.56%
# [Epoch 4/50] Train Loss: 1.7478 | Train Acc: 38.44% || Test Loss: 1.7568 | Test Acc: 39.13%
# [Epoch 5/50] Train Loss: 1.7288 | Train Acc: 38.90% || Test Loss: 1.7343 | Test Acc: 39.60%
# [Epoch 6/50] Train Loss: 1.7169 | Train Acc: 39.50% || Test Loss: 1.7379 | Test Acc: 39.81%
# [Epoch 7/50] Train Loss: 1.7087 | Train Acc: 39.74% || Test Loss: 1.7303 | Test Acc: 39.95%
# [Epoch 8/50] Train Loss: 1.7055 | Train Acc: 40.11% || Test Loss: 1.7302 | Test Acc: 39.97%
# [Epoch 9/50] Train Loss: 1.6972 | Train Acc: 40.43% || Test Loss: 1.7464 | Test Acc: 39.84%
# [Epoch 10/50] Train Loss: 1.6882 | Train Acc: 40.56% || Test Loss: 1.7264 | Test Acc: 40.68%
# [Epoch 11/50] Train Loss: 1.6842 | Train Acc: 40.64% || Test Loss: 1.7137 | Test Acc: 40.35%
# [Epoch 12/50] Train Loss: 1.6864 | Train Acc: 40.64% || Test Loss: 1.7408 | Test Acc: 40.16%
# [Epoch 13/50] Train Loss: 1.6784 | Train Acc: 40.90% || Test Loss: 1.7238 | Test Acc: 40.17%
# [Epoch 14/50] Train Loss: 1.6845 | Train Acc: 40.43% || Test Loss: 1.7400 | Test Acc: 40.30%
# [Epoch 15/50] Train Loss: 1.6797 | Train Acc: 41.01% || Test Loss: 1.7117 | Test Acc: 40.94%
# [Epoch 16/50] Train Loss: 1.6750 | Train Acc: 41.01% || Test Loss: 1.7239 | Test Acc: 40.20%
# [Epoch 17/50] Train Loss: 1.6762 | Train Acc: 40.60% || Test Loss: 1.6928 | Test Acc: 41.31%
# [Epoch 18/50] Train Loss: 1.6785 | Train Acc: 41.02% || Test Loss: 1.6931 | Test Acc: 41.31%
# [Epoch 19/50] Train Loss: 1.6697 | Train Acc: 40.99% || Test Loss: 1.7071 | Test Acc: 41.23%
# [Epoch 20/50] Train Loss: 1.6769 | Train Acc: 40.88% || Test Loss: 1.7066 | Test Acc: 41.13%
# [Epoch 21/50] Train Loss: 1.6723 | Train Acc: 41.13% || Test Loss: 1.7151 | Test Acc: 40.70%
# [Epoch 22/50] Train Loss: 1.6716 | Train Acc: 41.03% || Test Loss: 1.7056 | Test Acc: 41.17%
# [Epoch 23/50] Train Loss: 1.6714 | Train Acc: 41.52% || Test Loss: 1.7049 | Test Acc: 41.55%
# [Epoch 24/50] Train Loss: 1.6710 | Train Acc: 41.36% || Test Loss: 1.6961 | Test Acc: 41.18%
# [Epoch 25/50] Train Loss: 1.6709 | Train Acc: 40.94% || Test Loss: 1.7357 | Test Acc: 40.39%
# [Epoch 26/50] Train Loss: 1.6712 | Train Acc: 41.07% || Test Loss: 1.7099 | Test Acc: 41.02%
# [Epoch 27/50] Train Loss: 1.6757 | Train Acc: 41.05% || Test Loss: 1.7061 | Test Acc: 41.48%
# [Epoch 28/50] Train Loss: 1.6720 | Train Acc: 41.26% || Test Loss: 1.6920 | Test Acc: 42.16%
# [Epoch 29/50] Train Loss: 1.6715 | Train Acc: 41.21% || Test Loss: 1.7105 | Test Acc: 40.68%
# [Epoch 30/50] Train Loss: 1.6665 | Train Acc: 41.48% || Test Loss: 1.7100 | Test Acc: 41.39%
# [Epoch 31/50] Train Loss: 1.6677 | Train Acc: 41.30% || Test Loss: 1.7160 | Test Acc: 41.12%
# [Epoch 32/50] Train Loss: 1.6645 | Train Acc: 41.15% || Test Loss: 1.7084 | Test Acc: 41.30%
# [Epoch 33/50] Train Loss: 1.6730 | Train Acc: 40.97% || Test Loss: 1.6915 | Test Acc: 41.49%
# [Epoch 34/50] Train Loss: 1.6663 | Train Acc: 41.42% || Test Loss: 1.6772 | Test Acc: 42.03%
# [Epoch 35/50] Train Loss: 1.6744 | Train Acc: 40.81% || Test Loss: 1.7107 | Test Acc: 41.16%
# [Epoch 36/50] Train Loss: 1.6727 | Train Acc: 40.95% || Test Loss: 1.6978 | Test Acc: 41.31%
# [Epoch 37/50] Train Loss: 1.6677 | Train Acc: 41.14% || Test Loss: 1.7005 | Test Acc: 40.80%
# [Epoch 38/50] Train Loss: 1.6679 | Train Acc: 41.36% || Test Loss: 1.7076 | Test Acc: 41.33%
# [Epoch 39/50] Train Loss: 1.6701 | Train Acc: 41.07% || Test Loss: 1.7113 | Test Acc: 41.46%
# [Epoch 40/50] Train Loss: 1.6669 | Train Acc: 41.30% || Test Loss: 1.7054 | Test Acc: 41.27%
# [Epoch 41/50] Train Loss: 1.6686 | Train Acc: 41.06% || Test Loss: 1.7253 | Test Acc: 40.86%
# [Epoch 42/50] Train Loss: 1.6679 | Train Acc: 41.34% || Test Loss: 1.6814 | Test Acc: 41.61%
# [Epoch 43/50] Train Loss: 1.6603 | Train Acc: 41.71% || Test Loss: 1.7056 | Test Acc: 41.04%
# [Epoch 44/50] Train Loss: 1.6646 | Train Acc: 41.42% || Test Loss: 1.6919 | Test Acc: 41.72%
# [Epoch 45/50] Train Loss: 1.6603 | Train Acc: 41.56% || Test Loss: 1.7279 | Test Acc: 40.44%
# [Epoch 46/50] Train Loss: 1.6707 | Train Acc: 41.12% || Test Loss: 1.7475 | Test Acc: 40.28%
# [Epoch 47/50] Train Loss: 1.6689 | Train Acc: 41.36% || Test Loss: 1.6854 | Test Acc: 41.57%
# [Epoch 48/50] Train Loss: 1.6648 | Train Acc: 41.45% || Test Loss: 1.7081 | Test Acc: 41.15%
# [Epoch 49/50] Train Loss: 1.6698 | Train Acc: 41.01% || Test Loss: 1.6792 | Test Acc: 41.76%
# [Epoch 50/50] Train Loss: 1.6626 | Train Acc: 41.41% || Test Loss: 1.7007 | Test Acc: 41.64%
